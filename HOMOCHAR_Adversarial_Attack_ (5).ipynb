# %% [markdown]
# **What is TextAttack?**
#
# TextAttack is a Python framework for adversarial attacks, adversarial training, and data augmentation in NLP.TextAttack makes experimenting with the robustness of NLP models seamless, fast, and easy. It’s also useful for NLP model training, adversarial training, and data augmentation.
#
# **Why TextAttack?**
#
# There are lots of reasons to use TextAttack:
#
# **1)** Understand NLP models better by running different adversarial attacks on them and examining the output
#
# **2)** Research and develop different NLP adversarial attacks using the TextAttack framework and library of components
#
# **3)** Augment your dataset to increase model generalization and robustness downstream Train NLP models using just a single command !

# %% [markdown]
# **TextAttack is available through pip:**

# %%
# !pip install textattack
# !pip install tensorflow-text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.8/436.8 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 20.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 37.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.1 MB/s eta 0:00:00
# ...

# %%
import textattack
import transformers
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Help
# All of TextAttack's primary functionalities may be accessible by utilising the **textattack command**. To access detailed information about all commands, please go to

# %%
# !textattack --help
# Out:
# 2023-12-21 10:52:31.271627: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 10:52:31.271683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 10:52:31.273216: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 10:52:32.775256: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# usage: [python -m] textattack <command> [<args>]
#
# positional arguments:
#   {attack,attack-resume,augment,benchmark-recipe,eval,list,train,peek-dataset}
#                         textattack command helpers
# ...

# %% [markdown]
# An adversarial attack in NLP can be conducted via perturbing
# words and characters,  **swapping, deletion,
# insertion, mis-spelling, synonym replacement** etc., in a way
# such that the underlying meaning of the sentence will not
# change for the human observer but fools the model in giving
# wrong output.
#
# Each adversarial attack contains four essential components,
# which include transformation, search method, set of
# constraints, and a goal function.
#
# **Transformation:** A transformation that produces a
# number of potential perturbations from a single
# input.
#
# **Search method**: A search technique repeatedly
# probes the model and chooses promising
# perturbations from various transformations.
#
# **Constraints**: A group of restrictions used to assess
# the validity of a perturbation in relation to the
# original input.
#
# **Goal function:** A task-specific goal function that
# assesses the effectiveness of the attack in terms of
# model outputs.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f2278aea-b797-40bb-a426-30cd32d52559" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2278aea-b797-40bb-a426-30cd32d52559">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Picture1.png', width=525)

# %%
# !textattack list attack-recipes
# Out:
# 2023-12-21 10:52:56.257532: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 10:52:56.257586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 10:52:56.259106: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 10:52:57.715944: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# a2t (textattack.attack_recipes.A2TYoo2021)
# alzantot (textattack.attack_recipes.GeneticAlgorithmAlzantot2018)
# bae (textattack.attack_recipes.BAEGarg2019)
# bert-attack (textattack.attack_recipes.BERTAttackLi2020)
# ...

# %% [markdown]
# We will acquire the **emotion dataset** independently and then fine-tune it using a **transformer model**. Then **HOMOCHAR adversarial attack** is being performed on the learned model.

# %%
# !textattack peek-dataset --dataset-from-huggingface SetFit/emotion
# Out:
# 2023-12-21 10:53:11.399489: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 10:53:11.399548: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 10:53:11.401082: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 10:53:12.435303: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
# ...

# %% [markdown]
# **Training**

# %%
# !textattack train --model-name-or-path bert-base-uncased --dataset SetFit/emotion --model-num-labels 6 --model-max-length 64 --per-device-train-batch-size 128 --num-epochs 7
# Out:
# 2023-12-21 10:53:32.638886: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 10:53:32.638937: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 10:53:32.640100: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 10:53:34.054151: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading transformers AutoModelForSequenceClassification: bert-base-uncased
# config.json: 100% 570/570 [00:00<00:00, 4.25MB/s]
# model.safetensors: 100% 440M/440M [00:02<00:00, 205MB/s]
# ...

# %% [markdown]
# **Evaluation**

# %%
# !textattack eval --num-examples 1000 --model ./outputs/2023-12-21-10-53-38-316031/best_model/ --dataset-from-huggingface SetFit/emotion --dataset-split test
# Out:
# 2023-12-21 11:13:05.452719: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 11:13:05.452764: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 11:13:05.453972: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 11:13:06.541618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
# ...

# %%
# !textattack list goal-functions
# Out:
# 2023-12-21 11:17:37.322608: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 11:17:37.322654: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 11:17:37.323992: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 11:17:38.524012: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# hardlabel-classification (textattack.goal_functions.classification.HardLabelClassification)
# input-reduction (textattack.goal_functions.classification.InputReduction)
# minimize-bleu (textattack.goal_functions.text.MinimizeBleu)
# ...

# %%
# !textattack list constraints
# Out:
# 2023-12-21 11:17:50.402631: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 11:17:50.402686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 11:17:50.403874: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 11:17:51.636239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# bert (textattack.constraints.semantics.sentence_encoders.BERT)
# bert-score (textattack.constraints.semantics.BERTScore)
# bleu (textattack.constraints.overlap.BLEU)
# chrf (textattack.constraints.overlap.chrF)
# ...

# %%
# !textattack list transformations
# Out:
# 2023-12-21 11:18:08.514549: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 11:18:08.514598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 11:18:08.515722: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 11:18:09.560578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# random-synonym-insertion (textattack.transformations.RandomSynonymInsertion)
# word-deletion (textattack.transformations.WordDeletion)
# word-swap-embedding (textattack.transformations.WordSwapEmbedding)
# ...

# %%
# !textattack list search-methods
# Out:
# 2023-12-21 11:18:28.769195: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 11:18:28.769261: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 11:18:28.770857: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 11:18:30.242122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# beam-search (textattack.search_methods.BeamSearch)
# ga-word (textattack.search_methods.GeneticAlgorithm)
# greedy (textattack.search_methods.GreedySearch)
# greedy-word-wir (textattack.search_methods.GreedyWordSwapWIR)
# ...

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-85985b3b-4522-4fd7-ba4f-30e7acf753b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85985b3b-4522-4fd7-ba4f-30e7acf753b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('textattack_ecosystem (2).png', width=525)

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("./outputs/2023-12-21-10-53-38-316031/best_model/")
tokenizer = transformers.AutoTokenizer.from_pretrained("./outputs/2023-12-21-10-53-38-316031/best_model/")
model_wrapper = textattack.models.wrappers.HuggingFaceModelWrapper(model, tokenizer)

# %%
# !pip install torchfile
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5693 sha256=abb8fe6e7646f235826aed9af2f62f1c71c8f77f966221052d8fc41d079cd937
#   Stored in directory: /root/.cache/pip/wheels/c7/e9/87/1c51daf8e468d5c14931f8ac3344880f903ba96b063675cac2
# Successfully built torchfile
# ...

# %%
# Construct our four components for `Attack`

from textattack.constraints.pre_transformation import RepeatModification, StopwordModification

from textattack.constraints.semantics import WordEmbeddingDistance

# %%
goal_function = textattack.goal_functions.UntargetedClassification(model_wrapper)

constraints = [

    RepeatModification(),
    StopwordModification(),
    WordEmbeddingDistance(min_cos_sim=0.7)

]
# Out:
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/paragramcf.
# 100%|██████████| 481M/481M [00:15<00:00, 31.1MB/s]
# textattack: Unzipping file /root/.cache/textattack/tmp05g6s5hz.zip to /root/.cache/textattack/word_embeddings/paragramcf.
# textattack: Successfully saved word_embeddings/paragramcf to cache.

# %%
transformation = textattack.transformations.word_swaps.word_swap_homoglyph_swap.WordSwapHomoglyphSwap()
search_method = textattack.search_methods.BeamSearch(beam_width=8)

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0a965d00-bbf7-4892-80de-6dc531c6c92d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a965d00-bbf7-4892-80de-6dc531c6c92d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Picture2.png', width=525)

# %%
#attack = textattack.attack_recipes.textfooler_jin_2019.TextFoolerJin2019.build(model_wrapper)
attack =  textattack.Attack(goal_function, constraints, transformation, search_method)
dataset = textattack.datasets.HuggingFaceDataset("SetFit/emotion", dataset_columns=(["text"],'label'))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# textattack: Loading datasets dataset SetFit/emotion, split train.

# %%
attack_args = textattack.AttackArgs(

    num_examples=30,

    log_to_csv="result.csv",

    checkpoint_interval=2,

    checkpoint_dir="checkpoints",

    disable_stdout=True

)

attacker = textattack.Attacker(attack, dataset, attack_args)

attacker.attack_dataset()
# Out:
# textattack: Logging to CSV at path result.csv
# Attack(
#   (search_method): BeamSearch(
#     (beam_width):  8
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapHomoglyphSwap
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.7
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
#       )
#     (1): RepeatModification
#     (2): StopwordModification
#   (is_black_box):  True
# )
# [Succeeded / Failed / Skipped / Total] 2 / 0 / 0 / 2:   7%|▋         | 2/30 [00:01<00:26,  1.05it/s]textattack: Saving checkpoint under "checkpoints/1703157804545.ta.chkpt" at 2023-12-21 11:23:24 after 2 attacks.
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 0 / 3:  10%|█         | 3/30 [00:02<00:18,  1.44it/s]
# ...

# %%
from textattack import Attacker

attacker = Attacker(attack, dataset)
attack_results=attacker.attack_dataset()
# Out:
# Attack(
#   (search_method): BeamSearch(
#     (beam_width):  8
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapHomoglyphSwap
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.7
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
#       )
#     (1): RepeatModification
#     (2): StopwordModification
#   (is_black_box):  True
# )
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 0 / 1:  10%|█         | 1/10 [00:00<00:01,  6.36it/s]
# --------------------------------------------- Result 1 ---------------------------------------------
# [[0 (100%)]] --> [[3 (100%)]]
#
# i didnt feel [[humiliated]]
#
# i didnt feel [[humiliatеd]]
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 0 / 3:  30%|███       | 3/10 [00:00<00:01,  5.48it/s]
# ...

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d93852d0-02ca-495d-b589-1a55501d0fdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d93852d0-02ca-495d-b589-1a55501d0fdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Picture4.png', width=525)
